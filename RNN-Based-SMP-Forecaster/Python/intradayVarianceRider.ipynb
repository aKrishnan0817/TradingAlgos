# %%
 # importing basic packages

import pandas as pd
import numpy as np
import yfinance as yf
import datetime as dt
import plotly.express as px
import math
import matplotlib.pyplot as plt
import plotly.graph_objects as go

# %%
#mounting the notebook to my drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#setting the directory to the proper folder
import os
os.chdir("/content/drive/My Drive/Stock Algorithim/Datasets/frd_sample_futures_NQ")

# %%
NQ= pd.read_csv('NQ_1min_sample.csv')

# %%
NQ.head(-5)
# Out:
#                  timestamp      open      high       low     close  volume
# 0      2023-09-24 18:00:00  14880.25  14893.50  14880.25  14887.75     461
# 1      2023-09-24 18:01:00  14887.75  14893.25  14887.75  14893.00     159
# 2      2023-09-24 18:02:00  14892.00  14898.00  14890.00  14895.50     215
# 3      2023-09-24 18:03:00  14896.50  14897.75  14892.25  14896.25     104
# 4      2023-09-24 18:04:00  14895.50  14897.75  14893.75  14897.75      84
# ...                    ...       ...       ...       ...       ...     ...
# 15169  2023-10-09 16:50:00  15188.50  15189.75  15187.25  15187.25      73
# 15170  2023-10-09 16:51:00  15187.75  15190.00  15187.00  15189.50      90
# 15171  2023-10-09 16:52:00  15190.00  15194.75  15190.00  15193.75     229
# 15172  2023-10-09 16:53:00  15193.50  15195.00  15192.75  15193.50     110
# 15173  2023-10-09 16:54:00  15193.00  15193.50  15192.00  15192.50      66
#
# [15174 rows x 6 columns]

# %%
pd.to_datetime(NQ.loc[len(NQ)-1,"timestamp"])-pd.to_datetime(NQ.loc[0,"timestamp"])
# Out:
# Timedelta('14 days 22:59:00')
